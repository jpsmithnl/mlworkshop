# %% [markdown]
# # Welcome to Jupyter Notebook

# %% [markdown]
# You're probably running this on a SageMaker Notebook instance

# %% [markdown]
# This document is a notebook. They are tools for 'literate programming'. They contain your code, the output from running your code as well as notes.
#
# They're useful for:
# * _Exploratory coding:_ When you don't know in advance exactly what you need to do, you write a little bit of code, run it, maybe look at a plot or widget, go back and tweak it, run it again, and so on. It's a good pattern for Data Science.
# * _Sharing your work:_ These documents explain and demonstrate what you're doing. You can even use the 'RISE' extension to write presentations about Data or Code. When you're done you can save this document to Git, download it as PDF/HTML/RevealJs and share it with poeple. BinderHub is a tool which runs off Git to share any notebook you've committed.
#
# But it's not the right tool for all programming: as code gets more complicated, we move pieces of it out into modules so that we can reuse it in several files.

# %% [markdown]
# ## Contents
#
# * [To Run Code](#RunCode)
# * [Getting Help](#Help)
# * [Neat Things Jupyter Does](#NeatThings)
# * [Using Bash](#Bash)
# * [Other Languages](#OtherLanguages)
# * [Machine Learning](#MachineLearning)

# %% [markdown]
# <a href="#RunCode"></a>
# ## To Run Code

# %% [markdown]
# Notebooks are organized into cells. There are different kinds. The words you're reading are in a Markdown cell. Below is a code cell. To change cell types use the menu or the `Esc`+`M` and `Esc`+`Y` hotkeys.

# %%
# this is some code
import numpy as np
my_var = np.array((42,42))
my_var
# Out:
# array([42, 42])

# %% [markdown]
# To run a code cell select the cell and press `Shift`+`Enter` or the &#x25B6; button on the toolbar. The last variable in the cell is printed unless you end the line with `;`. You can go back an rerun the cell and the number by the cell will update -  they don't have to be run in order.
#
# The code in this notebook may not have been run yet.
#
# When a cell is not run it shows `In [ ]`
#
# When a cell is running it shows `In [*]`
#
# When a cell is done running it shows `In [1]` where the number is the order in which cells were run.

# %%
# To autocomplete place cursor after the dot and press tab
my_var.shape
# Out:
# (2,)

# %% [markdown]
# <a href="#Help"></a>
# ## Getting Help

# %% [markdown]
# If you need help with a specific function use `?`

# %%
my_var.byteswap?

# %% [markdown]
# To get the function's code use `??`

# %% [markdown]
# <a href="#NeatThings"></a>
# ## Neat Things Jupyter Does

# %% [markdown]
# Jupyter also supports ipython _magics_ which start with `%`

# %%
# %time sum(my_var)
# Out:
# CPU times: user 7 µs, sys: 7 µs, total: 14 µs
# Wall time: 18.6 µs
# 84

# %% [markdown]
# Jupyter supports right output like tables or charts. You don't need to call plt.show(), if `%matplotlib inline` is used it'll call it for you.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 10, 1000)
y = t
for omega in range(1,8):
    y = y * np.sin(omega * t)
    plt.plot(t, y)

# %% [markdown]
# There are a lot of great hotkeys for insert/delete cell, interrupting the currently executing cell, etc. Check out the &#x2328; icon from the menu.

# %% [markdown]
# Extensions are installed tools that you can configure from the main menu. They add extra functionality to the notebook.

# %% [markdown]
# ipywidgets allow for interaction when your notebook is still 'live'.

# %%
from ipywidgets import interact
@interact(x=True, y=1.0)
def g(x, y):
    return (x, y)
# Out:
# interactive(children=(Checkbox(value=True, description='x'), FloatSlider(value=1.0, description='y', max=3.0, …

# %% [markdown]
# The core of Jupyter can also be used to make custom web objects

# %%
from IPython.core.display import display, HTML
display(HTML('<p style="background-color:Tomato;">Lorem ipsum...</p>'))
# Out:
# <p style="background-color:Tomato;">Lorem ipsum...</p>

# %% [markdown]
# <a href="#Bash"></a>
# ## Using Bash

# %% [markdown]
# If you start a code cell with `!` it allows you to run terminal commands.

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/1 Intro to Jupyter_2019-04-07

# %% [markdown]
# Using this utility you can install new libraries into the conda_python3 kernel

# %%
# !sudo bash /home/ec2-user/SageMaker/Commons/add_library.sh numpy

# %%
# !aws s3 ls s3://foobar/

# %% [markdown]
# <a href="#OtherLanguages"></a>
# ## Using Other Languages
#
#
# If they're installed you can use several languages like R, JavaScript and Java from notebooks.

# %% [markdown]
# <a href="#MachineLearning"></a>
# ## Machine Learning

# %% [markdown]
# Notebooks are commonly used for Data Science.
# To read more about Machine Learning check out:
#
# [Hands-On Machine Learning with Scikit-Learn and TensorFlow - Aurelien Geron](http://shop.oreilly.com/product/0636920052289.do)
#
# The book uses several notebooks which are available at
# [github.com/ageron/handson-ml](github.com/ageron/handson-ml)
#
# For some online courses check out:
# * [fast.ai's practical intro to deep learning](https://www.fast.ai)
# * [Google's educational material](https://ai.google/education/)
# * [Amazon's training material](https://www.aws.training/LearningLibrary?filters=classification%3A30&search=&tab=view_all)
# * [Andrew Ng's course](https://www.coursera.org/learn/machine-learning)
